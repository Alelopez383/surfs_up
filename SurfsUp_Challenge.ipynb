# %% [markdown]
# # SurfsUp Challenge

# %%
# Import dependencies
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %%
# Dependencies
import numpy as np

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# Import the sqlalchemy extract function.
from sqlalchemy import extract

# %%
# 1. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
june_temp= session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)==6)

print(june_temp)
# Out:
# SELECT measurement.date AS measurement_date, measurement.tobs AS measurement_tobs
# FROM measurement
# WHERE CAST(STRFTIME('%m', measurement.date) AS INTEGER) = ?

# %%
# 2. Convert the June temperatures to a list.
june_results= session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)==6).all()

print(june_results)
# Out:
# [('2010-06-01', 78.0), ('2010-06-02', 76.0), ('2010-06-03', 78.0), ('2010-06-04', 76.0), ('2010-06-05', 77.0), ('2010-06-06', 78.0), ('2010-06-07', 77.0), ('2010-06-08', 78.0), ('2010-06-09', 78.0), ('2010-06-10', 79.0), ('2010-06-11', 78.0), ('2010-06-12', 78.0), ('2010-06-13', 78.0), ('2010-06-14', 77.0), ('2010-06-15', 78.0), ('2010-06-16', 78.0), ('2010-06-17', 77.0), ('2010-06-18', 77.0), ('2010-06-19', 82.0), ('2010-06-20', 78.0), ('2010-06-21', 78.0), ('2010-06-22', 78.0), ('2010-06-23', 78.0), ('2010-06-24', 78.0), ('2010-06-25', 77.0), ('2010-06-26', 76.0), ('2010-06-27', 78.0), ('2010-06-28', 78.0), ('2010-06-29', 78.0), ('2010-06-30', 78.0), ('2011-06-01', 77.0), ('2011-06-02', 78.0), ('2011-06-03', 73.0), ('2011-06-04', 70.0), ('2011-06-05', 76.0), ('2011-06-06', 77.0), ('2011-06-07', 77.0), ('2011-06-08', 77.0), ('2011-06-09', 77.0), ('2011-06-10', 78.0), ('2011-06-11', 77.0), ('2011-06-12', 77.0), ('2011-06-13', 78.0), ('2011-06-14', 78.0), ('2011-06-15', 77.0), ('2011-
# ...

# %%
# 3. Create a DataFrame from the list of temperatures for the month of June. 
june_df=pd.DataFrame(june_results,columns=['date','June Temps'])
june_df
# Out:
#             date  June Temps
# 0     2010-06-01        78.0
# 1     2010-06-02        76.0
# 2     2010-06-03        78.0
# 3     2010-06-04        76.0
# 4     2010-06-05        77.0
# ...          ...         ...
# 1695  2017-06-26        79.0
# 1696  2017-06-27        74.0
# 1697  2017-06-28        74.0
# 1698  2017-06-29        76.0
# 1699  2017-06-30        75.0
#
# [1700 rows x 2 columns]

# %%
# 4. Calculate and print out the summary statistics for the June temperature DataFrame.
june_df.describe()
# Out:
#         June Temps
# count  1700.000000
# mean     74.944118
# std       3.257417
# min      64.000000
# 25%      73.000000
# 50%      75.000000
# 75%      77.000000
# max      85.000000

# %%
june_stats_df=pd.DataFrame(june_df.describe())

# %%
# 5. Return to your challenge instructions to compare your summary statistics

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
dec_temp= session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)==12)

print(dec_temp)
# Out:
# SELECT measurement.date AS measurement_date, measurement.tobs AS measurement_tobs
# FROM measurement
# WHERE CAST(STRFTIME('%m', measurement.date) AS INTEGER) = ?

# %%
# 7. Convert the December temperatures to a list.
dec_results= session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)==12).all()

print(dec_results)
# Out:
# [('2010-12-01', 76.0), ('2010-12-03', 74.0), ('2010-12-04', 74.0), ('2010-12-06', 64.0), ('2010-12-07', 64.0), ('2010-12-08', 67.0), ('2010-12-09', 77.0), ('2010-12-10', 66.0), ('2010-12-11', 69.0), ('2010-12-12', 68.0), ('2010-12-13', 68.0), ('2010-12-14', 71.0), ('2010-12-15', 74.0), ('2010-12-16', 67.0), ('2010-12-17', 66.0), ('2010-12-18', 69.0), ('2010-12-19', 71.0), ('2010-12-23', 70.0), ('2010-12-24', 70.0), ('2010-12-26', 74.0), ('2010-12-27', 74.0), ('2010-12-28', 71.0), ('2010-12-29', 75.0), ('2010-12-30', 75.0), ('2010-12-31', 72.0), ('2011-12-01', 69.0), ('2011-12-02', 68.0), ('2011-12-03', 73.0), ('2011-12-04', 74.0), ('2011-12-05', 73.0), ('2011-12-06', 73.0), ('2011-12-07', 73.0), ('2011-12-08', 73.0), ('2011-12-09', 71.0), ('2011-12-10', 73.0), ('2011-12-11', 73.0), ('2011-12-12', 77.0), ('2011-12-13', 72.0), ('2011-12-14', 71.0), ('2011-12-15', 73.0), ('2011-12-16', 70.0), ('2011-12-17', 73.0), ('2011-12-18', 69.0), ('2011-12-19', 74.0), ('2011-12-20', 72.0), ('2011-
# ...

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
dec_df=pd.DataFrame(dec_results,columns=['date','Dec Temps'])
dec_df
# Out:
#             date  Dec Temps
# 0     2010-12-01       76.0
# 1     2010-12-03       74.0
# 2     2010-12-04       74.0
# 3     2010-12-06       64.0
# 4     2010-12-07       64.0
# ...          ...        ...
# 1512  2016-12-27       71.0
# 1513  2016-12-28       71.0
# 1514  2016-12-29       69.0
# 1515  2016-12-30       65.0
# 1516  2016-12-31       65.0
#
# [1517 rows x 2 columns]

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
dec_df.describe()
# Out:
#          Dec Temps
# count  1517.000000
# mean     71.041529
# std       3.745920
# min      56.000000
# 25%      69.000000
# 50%      71.000000
# 75%      74.000000
# max      83.000000

# %%
dec_stats_df=pd.DataFrame(dec_df.describe())

# %%
# 10. Return to your challenge instructions to compare your summary statistics

# %% [markdown]
# # EXTRA: Determine the Summary Statistics for July

# %%
july_temp= session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)==7)

print(july_temp)
# Out:
# SELECT measurement.date AS measurement_date, measurement.tobs AS measurement_tobs
# FROM measurement
# WHERE CAST(STRFTIME('%m', measurement.date) AS INTEGER) = ?

# %%
july_results= session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)==7).all()

print(july_results)
# Out:
# [('2010-07-01', 75.0), ('2010-07-02', 77.0), ('2010-07-03', 77.0), ('2010-07-04', 78.0), ('2010-07-05', 78.0), ('2010-07-06', 76.0), ('2010-07-07', 74.0), ('2010-07-08', 76.0), ('2010-07-09', 74.0), ('2010-07-10', 76.0), ('2010-07-11', 78.0), ('2010-07-12', 77.0), ('2010-07-13', 80.0), ('2010-07-16', 78.0), ('2010-07-17', 76.0), ('2010-07-18', 77.0), ('2010-07-19', 77.0), ('2010-07-21', 80.0), ('2010-07-22', 78.0), ('2010-07-24', 80.0), ('2010-07-25', 79.0), ('2010-07-26', 78.0), ('2010-07-27', 79.0), ('2010-07-28', 78.0), ('2010-07-29', 79.0), ('2010-07-30', 78.0), ('2010-07-31', 77.0), ('2011-07-01', 77.0), ('2011-07-02', 78.0), ('2011-07-03', 78.0), ('2011-07-04', 78.0), ('2011-07-05', 78.0), ('2011-07-06', 76.0), ('2011-07-07', 76.0), ('2011-07-08', 77.0), ('2011-07-09', 77.0), ('2011-07-10', 77.0), ('2011-07-11', 78.0), ('2011-07-12', 77.0), ('2011-07-13', 73.0), ('2011-07-14', 77.0), ('2011-07-15', 79.0), ('2011-07-16', 78.0), ('2011-07-17', 77.0), ('2011-07-18', 78.0), ('2011-
# ...

# %%
july_df=pd.DataFrame(july_results,columns=['date','July Temps'])
july_df
# Out:
#             date  July Temps
# 0     2010-07-01        75.0
# 1     2010-07-02        77.0
# 2     2010-07-03        77.0
# 3     2010-07-04        78.0
# 4     2010-07-05        78.0
# ...          ...         ...
# 1706  2017-07-27        75.0
# 1707  2017-07-28        73.0
# 1708  2017-07-29        77.0
# 1709  2017-07-30        79.0
# 1710  2017-07-31        74.0
#
# [1711 rows x 2 columns]

# %%
july_df.describe()
# Out:
#         July Temps
# count  1711.000000
# mean     76.082408
# std       3.356532
# min      61.000000
# 25%      74.000000
# 50%      76.000000
# 75%      78.000000
# max      87.000000

# %%
july_stats_df=pd.DataFrame(july_df.describe())

# %% [markdown]
# # EXTRA: Determine the Summary Statistics for August

# %%
aug_temp= session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)==8)

print(aug_temp)
# Out:
# SELECT measurement.date AS measurement_date, measurement.tobs AS measurement_tobs
# FROM measurement
# WHERE CAST(STRFTIME('%m', measurement.date) AS INTEGER) = ?

# %%
aug_results= session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)==8).all()

print(aug_results)
# Out:
# [('2010-08-01', 77.0), ('2010-08-02', 76.0), ('2010-08-03', 77.0), ('2010-08-04', 77.0), ('2010-08-05', 75.0), ('2010-08-06', 75.0), ('2010-08-07', 80.0), ('2010-08-08', 77.0), ('2010-08-09', 78.0), ('2010-08-10', 78.0), ('2010-08-11', 77.0), ('2010-08-12', 76.0), ('2010-08-13', 78.0), ('2010-08-14', 78.0), ('2010-08-15', 76.0), ('2010-08-16', 76.0), ('2010-08-17', 74.0), ('2010-08-18', 77.0), ('2010-08-19', 79.0), ('2010-08-20', 79.0), ('2010-08-21', 79.0), ('2010-08-22', 75.0), ('2010-08-23', 87.0), ('2010-08-24', 78.0), ('2010-08-25', 76.0), ('2010-08-26', 78.0), ('2010-08-27', 78.0), ('2010-08-28', 79.0), ('2010-08-29', 78.0), ('2010-08-30', 78.0), ('2010-08-31', 80.0), ('2011-08-01', 78.0), ('2011-08-02', 77.0), ('2011-08-03', 78.0), ('2011-08-04', 76.0), ('2011-08-05', 78.0), ('2011-08-06', 77.0), ('2011-08-07', 78.0), ('2011-08-08', 78.0), ('2011-08-09', 79.0), ('2011-08-11', 78.0), ('2011-08-12', 78.0), ('2011-08-13', 76.0), ('2011-08-14', 78.0), ('2011-08-15', 77.0), ('2011-
# ...

# %%
aug_df=pd.DataFrame(aug_results,columns=['date','Aug Temps'])
aug_df
# Out:
#             date  Aug Temps
# 0     2010-08-01       77.0
# 1     2010-08-02       76.0
# 2     2010-08-03       77.0
# 3     2010-08-04       77.0
# 4     2010-08-05       75.0
# ...          ...        ...
# 1617  2017-08-19       71.0
# 1618  2017-08-20       78.0
# 1619  2017-08-21       76.0
# 1620  2017-08-22       76.0
# 1621  2017-08-23       76.0
#
# [1622 rows x 2 columns]

# %%
aug_df.describe()
# Out:
#          Aug Temps
# count  1622.000000
# mean     76.412454
# std       3.453138
# min      65.000000
# 25%      74.000000
# 50%      76.000000
# 75%      79.000000
# max      87.000000

# %%
aug_stats_df=pd.DataFrame(aug_df.describe())

# %% [markdown]
# # EXTRA: Determine the Summary Statistics for September

# %%
sept_temp= session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)==9)

print(sept_temp)
# Out:
# SELECT measurement.date AS measurement_date, measurement.tobs AS measurement_tobs
# FROM measurement
# WHERE CAST(STRFTIME('%m', measurement.date) AS INTEGER) = ?

# %%
sept_results= session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)==9).all()

print(sept_results)
# Out:
# [('2010-09-01', 77.0), ('2010-09-02', 76.0), ('2010-09-03', 78.0), ('2010-09-04', 77.0), ('2010-09-05', 77.0), ('2010-09-06', 77.0), ('2010-09-07', 76.0), ('2010-09-08', 78.0), ('2010-09-09', 78.0), ('2010-09-10', 78.0), ('2010-09-11', 78.0), ('2010-09-12', 74.0), ('2010-09-13', 78.0), ('2010-09-14', 79.0), ('2010-09-15', 77.0), ('2010-09-16', 79.0), ('2010-09-17', 78.0), ('2010-09-19', 78.0), ('2010-09-20', 78.0), ('2010-09-21', 79.0), ('2010-09-22', 76.0), ('2010-09-23', 78.0), ('2010-09-24', 78.0), ('2010-09-25', 79.0), ('2010-09-26', 74.0), ('2010-09-27', 75.0), ('2010-09-28', 75.0), ('2010-09-29', 78.0), ('2010-09-30', 73.0), ('2011-09-02', 79.0), ('2011-09-03', 78.0), ('2011-09-04', 77.0), ('2011-09-05', 77.0), ('2011-09-06', 73.0), ('2011-09-07', 73.0), ('2011-09-08', 77.0), ('2011-09-09', 79.0), ('2011-09-10', 77.0), ('2011-09-11', 77.0), ('2011-09-12', 85.0), ('2011-09-13', 77.0), ('2011-09-14', 76.0), ('2011-09-15', 79.0), ('2011-09-16', 79.0), ('2011-09-17', 77.0), ('2011-
# ...

# %%
sept_df=pd.DataFrame(sept_results,columns=['date','Sept Temps'])
sept_df
# Out:
#             date  Sept Temps
# 0     2010-09-01        77.0
# 1     2010-09-02        76.0
# 2     2010-09-03        78.0
# 3     2010-09-04        77.0
# 4     2010-09-05        77.0
# ...          ...         ...
# 1475  2016-09-26        74.0
# 1476  2016-09-27        74.0
# 1477  2016-09-28        77.0
# 1478  2016-09-29        77.0
# 1479  2016-09-30        73.0
#
# [1480 rows x 2 columns]

# %%
sept_df.describe()
# Out:
#         Sept Temps
# count  1480.000000
# mean     76.164865
# std       3.535178
# min      64.000000
# 25%      74.000000
# 50%      76.000000
# 75%      79.000000
# max      87.000000

# %%
sept_stats_df=pd.DataFrame(sept_df.describe())

# %% [markdown]
# # EXTRA: Determine the Summary Statistics for October

# %%
oct_temp= session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)==10)

print(oct_temp)
# Out:
# SELECT measurement.date AS measurement_date, measurement.tobs AS measurement_tobs
# FROM measurement
# WHERE CAST(STRFTIME('%m', measurement.date) AS INTEGER) = ?

# %%
oct_results= session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)==10).all()

print(oct_results)
# Out:
# [('2010-10-01', 78.0), ('2010-10-02', 78.0), ('2010-10-03', 78.0), ('2010-10-04', 78.0), ('2010-10-05', 80.0), ('2010-10-06', 79.0), ('2010-10-07', 79.0), ('2010-10-08', 78.0), ('2010-10-09', 78.0), ('2010-10-10', 78.0), ('2010-10-11', 77.0), ('2010-10-12', 79.0), ('2010-10-13', 78.0), ('2010-10-15', 78.0), ('2010-10-16', 77.0), ('2010-10-17', 76.0), ('2010-10-18', 76.0), ('2010-10-19', 72.0), ('2010-10-20', 74.0), ('2010-10-21', 80.0), ('2010-10-22', 77.0), ('2010-10-23', 75.0), ('2010-10-24', 78.0), ('2010-10-25', 78.0), ('2010-10-26', 76.0), ('2010-10-27', 79.0), ('2010-10-28', 78.0), ('2010-10-29', 78.0), ('2010-10-30', 77.0), ('2010-10-31', 76.0), ('2011-10-01', 78.0), ('2011-10-02', 78.0), ('2011-10-03', 80.0), ('2011-10-05', 79.0), ('2011-10-06', 75.0), ('2011-10-07', 78.0), ('2011-10-08', 79.0), ('2011-10-09', 78.0), ('2011-10-10', 77.0), ('2011-10-11', 78.0), ('2011-10-12', 77.0), ('2011-10-13', 77.0), ('2011-10-14', 78.0), ('2011-10-15', 77.0), ('2011-10-16', 76.0), ('2011-
# ...

# %%
oct_df=pd.DataFrame(oct_results,columns=['date','Oct Temps'])
oct_df
# Out:
#             date  Oct Temps
# 0     2010-10-01       78.0
# 1     2010-10-02       78.0
# 2     2010-10-03       78.0
# 3     2010-10-04       78.0
# 4     2010-10-05       80.0
# ...          ...        ...
# 1551  2016-10-27       71.0
# 1552  2016-10-28       68.0
# 1553  2016-10-29       71.0
# 1554  2016-10-30       76.0
# 1555  2016-10-31       69.0
#
# [1556 rows x 2 columns]

# %%
oct_df.describe()
# Out:
#          Oct Temps
# count  1556.000000
# mean     75.391388
# std       3.545084
# min      64.000000
# 25%      73.000000
# 50%      76.000000
# 75%      78.000000
# max      86.000000

# %%
oct_stats_df=pd.DataFrame(oct_df.describe())
oct_stats_df
# Out:
#          Oct Temps
# count  1556.000000
# mean     75.391388
# std       3.545084
# min      64.000000
# 25%      73.000000
# 50%      76.000000
# 75%      78.000000
# max      86.000000

# %% [markdown]
# # EXTRA: Determine the Summary Statistics for November

# %%
nov_temp= session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)==11)

print(nov_temp)
# Out:
# SELECT measurement.date AS measurement_date, measurement.tobs AS measurement_tobs
# FROM measurement
# WHERE CAST(STRFTIME('%m', measurement.date) AS INTEGER) = ?

# %%
nov_results= session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)==11).all()

print(nov_results)
# Out:
# [('2010-11-01', 75.0), ('2010-11-02', 73.0), ('2010-11-04', 73.0), ('2010-11-05', 77.0), ('2010-11-06', 76.0), ('2010-11-07', 77.0), ('2010-11-08', 76.0), ('2010-11-09', 73.0), ('2010-11-10', 73.0), ('2010-11-11', 77.0), ('2010-11-12', 77.0), ('2010-11-13', 76.0), ('2010-11-16', 73.0), ('2010-11-17', 73.0), ('2010-11-19', 72.0), ('2010-11-20', 69.0), ('2010-11-21', 69.0), ('2010-11-22', 68.0), ('2010-11-23', 69.0), ('2010-11-24', 76.0), ('2010-11-25', 76.0), ('2010-11-27', 75.0), ('2010-11-28', 74.0), ('2010-11-29', 69.0), ('2010-11-30', 74.0), ('2011-11-01', 71.0), ('2011-11-02', 77.0), ('2011-11-03', 77.0), ('2011-11-04', 75.0), ('2011-11-05', 76.0), ('2011-11-06', 77.0), ('2011-11-07', 78.0), ('2011-11-08', 76.0), ('2011-11-09', 76.0), ('2011-11-10', 76.0), ('2011-11-11', 74.0), ('2011-11-12', 75.0), ('2011-11-13', 76.0), ('2011-11-14', 73.0), ('2011-11-15', 71.0), ('2011-11-16', 75.0), ('2011-11-17', 76.0), ('2011-11-18', 78.0), ('2011-11-19', 76.0), ('2011-11-20', 75.0), ('2011-
# ...

# %%
nov_df=pd.DataFrame(nov_results,columns=['date','Nov Temps'])
nov_df
# Out:
#             date  Nov Temps
# 0     2010-11-01       75.0
# 1     2010-11-02       73.0
# 2     2010-11-04       73.0
# 3     2010-11-05       77.0
# 4     2010-11-06       76.0
# ...          ...        ...
# 1483  2016-11-26       70.0
# 1484  2016-11-27       69.0
# 1485  2016-11-28       71.0
# 1486  2016-11-29       67.0
# 1487  2016-11-30       72.0
#
# [1488 rows x 2 columns]

# %%
nov_df.describe()
# Out:
#          Nov Temps
# count  1488.000000
# mean     73.252688
# std       3.617282
# min      61.000000
# 25%      71.000000
# 50%      74.000000
# 75%      76.000000
# max      83.000000

# %%
nov_stats_df=pd.DataFrame(nov_df.describe())

# %%
nov_stats_df
# Out:
#          Nov Temps
# count  1488.000000
# mean     73.252688
# std       3.617282
# min      61.000000
# 25%      71.000000
# 50%      74.000000
# 75%      76.000000
# max      83.000000

# %%
biannual_temps_df = pd.concat([june_stats_df,july_stats_df,aug_stats_df,sept_stats_df,oct_stats_df,nov_stats_df,dec_stats_df],axis=1)

# %%
biannual_temps_df
# Out:
#         June Temps   July Temps    Aug Temps   Sept Temps    Oct Temps  \
# count  1700.000000  1711.000000  1622.000000  1480.000000  1556.000000
# mean     74.944118    76.082408    76.412454    76.164865    75.391388
# std       3.257417     3.356532     3.453138     3.535178     3.545084
# min      64.000000    61.000000    65.000000    64.000000    64.000000
# 25%      73.000000    74.000000    74.000000    74.000000    73.000000
# 50%      75.000000    76.000000    76.000000    76.000000    76.000000
# 75%      77.000000    78.000000    79.000000    79.000000    78.000000
# max      85.000000    87.000000    87.000000    87.000000    86.000000
#
#          Nov Temps    Dec Temps
# count  1488.000000  1517.000000
# mean     73.252688    71.041529
# std       3.617282     3.745920
# min      61.000000    56.000000
# 25%      71.000000    69.000000
# 50%      74.000000    71.000000
# 75%      76.000000    74.000000
# max      83.000000    83.000000
